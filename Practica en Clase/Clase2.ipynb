# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
img=cv2.imread('colores.jpg')
img_rgb=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

fig, axs = plt.subplots(1, 4, figsize=(15, 5))

axs[0].imshow(img_rgb)
axs[0].set_title('Imagen Original')

fig_img = axs [1].imshow(img_rgb[...,0], cmap='gray')
fig.colorbar(fig_img, ax=axs[1],shrink=0.5)
axs[1].set_title('Canal Rojo')

fig_img = axs [2].imshow(img_rgb[...,1], cmap='gray')
fig.colorbar(fig_img, ax=axs[2],shrink=0.5)
axs[2].set_title('Canal Verde')

fig_img = axs [3].imshow(img_rgb[...,2], cmap='gray')
fig.colorbar(fig_img, ax=axs[3],shrink=0.5)
axs[3].set_title('Canal Azul')
# Out:
# Text(0.5, 1.0, 'Canal Azul')

# %%
img_rgb[:3,:3,:]
# Out:
# array([[[201, 140, 255],
#         [200, 139, 255],
#         [197, 133, 255]],
#
#        [[205, 141, 255],
#         [204, 140, 255],
#         [201, 135, 255]],
#
#        [[206, 138, 255],
#         [206, 138, 255],
#         [205, 135, 255]]], dtype=uint8)

# %%
plt.imshow(img_rgb[:10, :10, :])  # para mostrar los primeros 10 pixeles de cada canal (recortar la imagen)

# %%
cv2.imwrite('colores.jpg', img_rgb)#guardar con opencv
plt.imsave('colores_nuevo.jpg',cv2.cvtColor(img_rgb,cv2.COLOR_BGR2RGB))

# %% [markdown]
# EJERCICIO PARA CREAR IMAGEN

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['figure.figsize'] = (10, 5)
size_imagen = 100
R= np.ones((size_imagen, size_imagen)) * 255
G= np.ones((size_imagen, size_imagen)) * 128
B= np.ones((size_imagen, size_imagen)) * 0

imagen=np.dstack((R,G,B))
imagen=np.array (imagen, dtype=int)

plt.figure()
plt.imshow(imagen) 
plt.title('imagen de color : naranja')
plt.show()

# %% [markdown]
# ESCALA DE GRISES

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
img=cv2.imread('colores.jpg',cv2.IMREAD_GRAYSCALE)
#valores iniciales de profundidad de color
original= img.dtype
#transformando img a 16 bits
img16bits=np.uint16(img) 
img_new=img16bits.dtype
print('profundidad del color:', img_new)

#guardado con cv2
cv2.imwrite('colores.jpg', img)#guardar con opencv

#guardado con pyplot 
plt.imsave('colores_16bits.jpg',cv2.cvtColor(img,cv2.COLOR_BGR2RGB))


plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.title('Imagen original')
plt.imshow(img, cmap='gray')

plt.subplot(1,2,2)
plt.title('Imagen con 16 bits')
plt.imshow(img16bits, cmap='gray')
# Out:
# profundidad del color: uint16
